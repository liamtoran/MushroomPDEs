# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.animation as animation
import numpy as np
import scipy.sparse as sp
from scipy.sparse.linalg.dsolve import spsolve
from scipy.sparse.linalg import bicgstab, bicg, cg, cgs, gmres, lgmres, minres, qmr, gcrotmk
from IPython.display import HTML
import time
#%matplotlib inline

# %%
def coeffs_P3():
    a = (lbda+f0)/T
    b = (f0**2+lbda*f0 -f0*F0)/T
    c = -F0*f0*(lbda+2*f0)/T
    d = (F0*f0)**2/T
    return [a,b,c,d]

# %%
def coeffs_Q():
    a,b,c,d = coeffs_P3()
    return [a, 2*b, 3*c, 4*d]

def vitesse_theorique(epsilon= .001,sign=-1):
    roots_Q = np.roots(coeffs_Q())
    candidats = [sign*1000*np.sqrt(T)]
    for x in roots_Q :
        p3_x = np.polyval(coeffs_P3(),x)
        if p3_x < 0:
            candidats += [sign*np.sqrt(-x**4/p3_x)]
    filtre = []
    for s in candidats:
        s_roots = np.roots([1]+[(s+sign*epsilon)**2*x for x in coeffs_P3()])
        s_roots = s_roots[np.isreal(s_roots)]
        if len(s_roots) == 4:
            filtre += [s]
    if sign == 1:
        s_theorique = np.min(filtre)
    else:
        s_theorique = np.max(filtre)
    return s_theorique
            
def plot_roots():
    X =[]
    for n in np.linspace(0,50,10000):
        s = n/2
        roots = np.roots([1]+[s**2*x for x in coeffs_P3()])
        roots = roots[np.isreal(roots)]
        for i in range(len(roots)):
            X+=[[s,roots[i]]]

    fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
    S = []
    Root = []
    for i in range(len(X)):
        S += [X[i][0]]
        Root += [X[i][1]]
    plt.figsize=(3,3)
    plt.axis((0,2*vitesse_theorique(sign=1),-20,1))
    plt.scatter(S,Root, marker='.')
    plt.axvline(x=vitesse_theorique(sign=1))

# %%
lbda, F0, f0, T = 1,1,1,1
plot_roots()
print(vitesse_theorique(sign=1))
# Out:
# /usr/lib/python3.7/site-packages/numpy/core/numeric.py:591: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# 2.488424998351927

# %%
lbda, F0, f0, T = 1000,1,1,1000
K = T/lbda
s_theorique_approx = np.sqrt(K * (f0*(18*F0+4) + np.sqrt(f0*(f0*(18*F0+4))**2+108*(f0+4*F0)*F0**2)) \
                             / (2*(f0+4*F0)))
plot_roots()
print('vitesse fluide:',vitesse_theorique(sign=1))
print('vitesse approximation KPP memoire',s_theorique_approx)
# Out:
# vitesse fluide: 2.322242335054333
# vitesse approximation KPP memoire 2.32379000772445

# %%
lbda, F0, f0, T = 1,1,1,1

X =[]
for n in np.linspace(0,50,10000):
    s = n/2
    roots = np.roots([1]+[s**2*x for x in coeffs_P3()])
    roots = roots[np.isreal(roots)]
    for i in range(len(roots)):
        X+=[[s,roots[i]]]

fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
S = []
Root = []
for i in range(len(X)):
    S += [X[i][0]]
    Root += [X[i][1]]
plt.figsize=(3,3)
plt.axis((0,2*vitesse_theorique(sign=1),-15,5))
plt.scatter(S,Root, marker='.')
plt.axvline(x=vitesse_theorique(sign=1))

# %%
##Below is just me checking stuff

# %%
roots
# Out:
# array([-1.24949860e+03, -1.61919385e+00,  6.17591278e-01,  5.00200643e-01])

# %%
roots_Q = np.roots(coeffs_Q())
candidats = [sign*1000*np.sqrt(T)]
for x in roots_Q :
    p3_x = np.polyval(coeffs_P3(),x)
    if p3_x < 0:
        candidats += [sign*np.sqrt(-x**4/p3_x)]
filtre = []
for s in candidats:
    s_roots = np.roots([1]+[(s+sign*epsilon)**2*x for x in coeffs_P3()])
    s_roots = s_roots[np.isreal(s_roots)]
    if len(s_roots) == 4:
        filtre += [s]
if sign == 1:
    s_theorique = np.min(filtre)
else:
    s_theorique = np.max(filtre)

# %%
sign = 1 
epsilon = .001

# %%
s_theorique
# Out:
# 2.488424998351927

# %%
roots_Q
# Out:
# array([-2.83565909,  1.28811008,  0.54754901])

# %%
foo = []
for x in roots_Q :
    p3_x = np.polyval(coeffs_P3(),x)
    print(-x**4/p3_x)
# Out:
# 2.304661165011987
# -0.8969201374347084
# 6.192258972422788

# %%
candidats
# Out:
# [1000.0, 1.5181110516072225, 2.488424998351927]

# %%
for s in candidats:
    s_roots = np.roots([1]+[(s+sign*epsilon)**2*x for x in coeffs_P3()])
    s_roots = s_roots[np.isreal(s_roots)]
    print(len(s_roots))
# Out:
# 4
# 2
# 4
