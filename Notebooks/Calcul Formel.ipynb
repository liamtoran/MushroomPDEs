# %%
from sympy import *

# %%
init_printing()

# %%
lbda = Symbol('\lambda')
f = Symbol('f_0')
F = Symbol('F_0')
s = Symbol('S')
Y = Symbol('Y')

# %%
#DISCRIMINANT DE Q

# %%
a = (lbda+f)
b = 2*f*(f+lbda-F)
c = -3*F*f*(lbda + 2*f)
d = 4*(f*F)**2
Q = a*Y**3 + b*Y**2 + c*Y + d
Q = Poly(Q,gens=Y)
Q
# Out:
# Poly((\lambda + f_0)*Y**3 + (-2*F_0*f_0 + 2*\lambda*f_0 + 2*f_0**2)*Y**2 + (-3
# *F_0*\lambda*f_0 - 6*F_0*f_0**2)*Y + 4*F_0**2*f_0**2, Y, domain='ZZ[F_0,\lambd
# a,f_0]')

# %%
discriminant(Q,Y)
# Out:
#       5   5        4        2   4         4           5         4   6
# 128⋅F₀ ⋅f₀  + 36⋅F₀ ⋅\lambda ⋅f₀  + 192⋅F₀ ⋅\lambda⋅f₀  + 192⋅F₀ ⋅f₀  + 108⋅F₀
#
# 3        4   3         3        3   4         3        2   5         3
#  ⋅\lambda ⋅f₀  + 252⋅F₀ ⋅\lambda ⋅f₀  + 240⋅F₀ ⋅\lambda ⋅f₀  + 192⋅F₀ ⋅\lambda
#
#    6        3   7        2        4   4        2        3   5        2
# ⋅f₀  + 96⋅F₀ ⋅f₀  + 36⋅F₀ ⋅\lambda ⋅f₀  + 88⋅F₀ ⋅\lambda ⋅f₀  + 84⋅F₀ ⋅\lambda
#
# 2   6        2           7        2   8
#  ⋅f₀  + 48⋅F₀ ⋅\lambda⋅f₀  + 16⋅F₀ ⋅f₀

# %%
Delta_Q = b**2*c**2 + 18*a*b*c*d -27*a**2*d**2 -4*a*c**3 -4*b**3*d
Delta_Q.expand()
# Out:
#       5   5        4        2   4         4           5         4   6
# 128⋅F₀ ⋅f₀  + 36⋅F₀ ⋅\lambda ⋅f₀  + 192⋅F₀ ⋅\lambda⋅f₀  + 192⋅F₀ ⋅f₀  + 108⋅F₀
#
# 3        4   3         3        3   4         3        2   5         3
#  ⋅\lambda ⋅f₀  + 252⋅F₀ ⋅\lambda ⋅f₀  + 240⋅F₀ ⋅\lambda ⋅f₀  + 192⋅F₀ ⋅\lambda
#
#    6        3   7        2        4   4        2        3   5        2
# ⋅f₀  + 96⋅F₀ ⋅f₀  + 36⋅F₀ ⋅\lambda ⋅f₀  + 88⋅F₀ ⋅\lambda ⋅f₀  + 84⋅F₀ ⋅\lambda
#
# 2   6        2           7        2   8
#  ⋅f₀  + 48⋅F₀ ⋅\lambda⋅f₀  + 16⋅F₀ ⋅f₀

# %%
#DISCRIMINANT DE P_3

# %%
a = (lbda+f)
b = f*(f+lbda-F)
c = -F*f*(lbda + 2*f)
d = (f*F)**2
P = a*Y**3 + b*Y**2 + c*Y + d
P = Poly(P,gens=Y)

# %%
Delta_P = discriminant(P)
Delta_P.expand()
# Out:
#     5   5       4        2   4       4           5     4   6       3        4
# 4⋅F₀ ⋅f₀  - 8⋅F₀ ⋅\lambda ⋅f₀  - 8⋅F₀ ⋅\lambda⋅f₀  + F₀ ⋅f₀  + 4⋅F₀ ⋅\lambda ⋅
#
#   3       3        3   4       3        2   5       3           6     2
# f₀  + 8⋅F₀ ⋅\lambda ⋅f₀  + 2⋅F₀ ⋅\lambda ⋅f₀  - 2⋅F₀ ⋅\lambda⋅f₀  + F₀ ⋅\lambd
#
#  4   4       2        3   5     2        2   6
# a ⋅f₀  + 2⋅F₀ ⋅\lambda ⋅f₀  + F₀ ⋅\lambda ⋅f₀

# %%
#DISCRIMINANT DE A=Y⁴ + sP_3

# %%
a = 1
b = s*(lbda+f)
c = s*f*(f+lbda-F)
d = -s*F*f*(lbda + 2*f)
e = s*(f*F)**2
A = a*Y**4 + b *Y**3 + c * Y **2 + d *Y + e 
A = Poly(A,gens=Y)

# %%
Delta_A = 256*a**3*e**3 - 128*a**2*e**2*c**2 -4*b**3*d**3 + 16*a*c**4*e -4*a*c**3*d**2 \
-192*a**2*b*d*e**2 - 27*b**4*e**2 - 6*a*b**2*d**2*e +144*a*b**2*c*e**2 + \
144*a**2*c*d**2*e -80*a*b*c**2*d*e + 18*b**3*c*d*e +18*a*b*c*d**3 + b**2*c**2*d**2 \
-4*b**2*c**3*e -27*a**2*d**4

# %%
factor(Delta_A,s)
# Out:
#   2  3   3 ⎛      4   3    3 ⎛    3        2   2       3           3       3
# F₀ ⋅S ⋅f₀ ⋅⎝256⋅F₀ ⋅f₀  + S ⋅⎝4⋅F₀ ⋅\lambda ⋅f₀  + 8⋅F₀ ⋅\lambda⋅f₀  + 4⋅F₀ ⋅f
#
#  4       2        4           2        3   2        2        2   3       2
# ₀  - 8⋅F₀ ⋅\lambda ⋅f₀ - 24⋅F₀ ⋅\lambda ⋅f₀  - 23⋅F₀ ⋅\lambda ⋅f₀  - 6⋅F₀ ⋅\la
#
#        4     2   5               6                5                   4   2
# mbda⋅f₀  + F₀ ⋅f₀  + 4⋅F₀⋅\lambda  + 16⋅F₀⋅\lambda ⋅f₀ + 22⋅F₀⋅\lambda ⋅f₀  +
#
#              3   3               2   4                  5          6
# 10⋅F₀⋅\lambda ⋅f₀  - 2⋅F₀⋅\lambda ⋅f₀  - 2⋅F₀⋅\lambda⋅f₀  + \lambda ⋅f₀ + 4⋅\l
#
#      5   2            4   3            3   4          2   5⎞    2 ⎛     4   3
# ambda ⋅f₀  + 6⋅\lambda ⋅f₀  + 4⋅\lambda ⋅f₀  + \lambda ⋅f₀ ⎠ + S ⋅⎝16⋅F₀ ⋅f₀
#
#        3        2   2        3           3        3   4        2        4
# - 60⋅F₀ ⋅\lambda ⋅f₀  - 96⋅F₀ ⋅\lambda⋅f₀  - 32⋅F₀ ⋅f₀  + 12⋅F₀ ⋅\lambda ⋅f₀ +
#
#       2        3   2        2        2   3        2           4       2   5
#  62⋅F₀ ⋅\lambda ⋅f₀  + 74⋅F₀ ⋅\lambda ⋅f₀  + 16⋅F₀ ⋅\lambda⋅f₀  - 8⋅F₀ ⋅f₀  -
#
#              5                   4   2                3   3                  5
# 18⋅F₀⋅\lambda ⋅f₀ - 52⋅F₀⋅\lambda ⋅f₀  - 42⋅F₀⋅\lambda ⋅f₀  + 8⋅F₀⋅\lambda⋅f₀
#
#             5   2             4   3             3   4            2   5⎞     ⎛
#  - 4⋅\lambda ⋅f₀  - 12⋅\lambda ⋅f₀  - 12⋅\lambda ⋅f₀  - 4⋅\lambda ⋅f₀ ⎠ + S⋅⎝-
#
#        4   3        3        2   2         3           3        3   4        2
#  128⋅F₀ ⋅f₀  + 48⋅F₀ ⋅\lambda ⋅f₀  + 256⋅F₀ ⋅\lambda⋅f₀  + 64⋅F₀ ⋅f₀  - 27⋅F₀
#
#         4           2        3   2        2        2   3        2           4
# ⋅\lambda ⋅f₀ - 72⋅F₀ ⋅\lambda ⋅f₀  - 56⋅F₀ ⋅\lambda ⋅f₀  + 32⋅F₀ ⋅\lambda⋅f₀
#
#        2   5⎞⎞
# + 16⋅F₀ ⋅f₀ ⎠⎠

# %%
Disc_A=poly((Delta_A/s**3).expand(),gens=s)
factor(discriminant(Disc_A))
# Out:
#                                                          2
#      12        2   15 ⎛                 2               ⎞  ⎛     3   2       2
# 16⋅F₀  ⋅\lambda ⋅f₀  ⋅⎝4⋅F₀⋅f₀ - \lambda  - 2⋅\lambda⋅f₀⎠ ⋅⎝32⋅F₀ ⋅f₀  + 9⋅F₀
#
#
#         2           2           2        2   3                4
# ⋅\lambda ⋅f₀ + 48⋅F₀ ⋅\lambda⋅f₀  + 48⋅F₀ ⋅f₀  + 27⋅F₀⋅\lambda  + 63⋅F₀⋅\lambd
#
#
#  3                   2   2                   3           4            4
# a ⋅f₀ + 60⋅F₀⋅\lambda ⋅f₀  + 48⋅F₀⋅\lambda⋅f₀  + 24⋅F₀⋅f₀  + 9⋅\lambda ⋅f₀ + 2
#
#                                                           3
#          3   2             2   3                4       5⎞
# 2⋅\lambda ⋅f₀  + 21⋅\lambda ⋅f₀  + 12⋅\lambda⋅f₀  + 4⋅f₀ ⎠

# %%
#DISCRIMINANT POSITIF OU NUL!

# %%
lc = LC(Disc_A)
factor(lc)
# Out:
#                                                                    2
#   2   3                           2 ⎛               2             ⎞
# F₀ ⋅f₀ ⋅(4⋅F₀ + f₀)⋅(\lambda + f₀) ⋅⎝F₀⋅f₀ - \lambda  - \lambda⋅f₀⎠

# %%
#Coefficient dominant positif

# %%
a = 1
b = s*(lbda+f)
c = s*f*(f+lbda-F)
d = -s*F*f*(lbda + 2*f)
e = s*(f*F)**2
A = a*Y**4 + b *Y**3 + c * Y **2 + d *Y + e 
A = Poly(A,gens=Y)
A
# Out:
# Poly(Y**4 + (S*\lambda + S*f_0)*Y**3 + (-F_0*S*f_0 + S*\lambda*f_0 + S*f_0**2)
# *Y**2 + (-F_0*S*\lambda*f_0 - 2*F_0*S*f_0**2)*Y + F_0**2*S*f_0**2, Y, domain='
# ZZ[F_0,S,\lambda,f_0]')

# %%
A = a*Y**4 + b *Y**3 + c * Y **2 + d *Y + e 
B = simplify(A.subs(Y,Y-(b/4*a)).expand())
B = Poly(B,gens=Y)
B
# Out:
# Poly(Y**4 + (-F_0*S*f_0 - 3*S**2*\lambda**2/8 - 3*S**2*\lambda*f_0/4 - 3*S**2*
# f_0**2/8 + S*\lambda*f_0 + S*f_0**2)*Y**2 + (F_0*S**2*\lambda*f_0/2 + F_0*S**2
# *f_0**2/2 - F_0*S*\lambda*f_0 - 2*F_0*S*f_0**2 + S**3*\lambda**3/8 + 3*S**3*\l
# ambda**2*f_0/8 + 3*S**3*\lambda*f_0**2/8 + S**3*f_0**3/8 - S**2*\lambda**2*f_0
# /2 - S**2*\lambda*f_0**2 - S**2*f_0**3/2)*Y + F_0**2*S*f_0**2 - F_0*S**3*\lamb
# da**2*f_0/16 - F_0*S**3*\lambda*f_0**2/8 - F_0*S**3*f_0**3/16 + F_0*S**2*\lamb
# da**2*f_0/4 + 3*F_0*S**2*\lambda*f_0**2/4 + F_0*S**2*f_0**3/2 - 3*S**4*\lambda
# **4/256 - 3*S**4*\lambda**3*f_0/64 - 9*S**4*\lambda**2*f_0**2/128 - 3*S**4*\la
# mbda*f_0**3/64 - 3*S**4*f_0**4/256 + S**3*\lambda**3*f_0/16 + 3*S**3*\lambda**
# 2*f_0**2/16 + 3*S**3*\lambda*f_0**3/16 + S**3*f_0**4/16, Y, domain='QQ[F_0,S,\
# lambda,f_0]')

# %%
Delta_B = Poly(discriminant(B)/s**3,gens=s)
Delta_B
# Out:
# Poly((4*F_0**5*\lambda**2*f_0**5 + 8*F_0**5*\lambda*f_0**6 + 4*F_0**5*f_0**7 -
#  8*F_0**4*\lambda**4*f_0**4 - 24*F_0**4*\lambda**3*f_0**5 - 23*F_0**4*\lambda*
# *2*f_0**6 - 6*F_0**4*\lambda*f_0**7 + F_0**4*f_0**8 + 4*F_0**3*\lambda**6*f_0*
# *3 + 16*F_0**3*\lambda**5*f_0**4 + 22*F_0**3*\lambda**4*f_0**5 + 10*F_0**3*\la
# mbda**3*f_0**6 - 2*F_0**3*\lambda**2*f_0**7 - 2*F_0**3*\lambda*f_0**8 + F_0**2
# *\lambda**6*f_0**4 + 4*F_0**2*\lambda**5*f_0**5 + 6*F_0**2*\lambda**4*f_0**6 +
#  4*F_0**2*\lambda**3*f_0**7 + F_0**2*\lambda**2*f_0**8)*S**3 + (16*F_0**6*f_0*
# *6 - 60*F_0**5*\lambda**2*f_0**5 - 96*F_0**5*\lambda*f_0**6 - 32*F_0**5*f_0**7
#  + 12*F_0**4*\lambda**4*f_0**4 + 62*F_0**4*\lambda**3*f_0**5 + 74*F_0**4*\lamb
# da**2*f_0**6 + 16*F_0**4*\lambda*f_0**7 - 8*F_0**4*f_0**8 - 18*F_0**3*\lambda*
# *5*f_0**4 - 52*F_0**3*\lambda**4*f_0**5 - 42*F_0**3*\lambda**3*f_0**6 + 8*F_0*
# *3*\lambda*f_0**8 - 4*F_0**2*\lambda**5*f_0**5 - 12*F_0**2*\lambda**4*f_0**6 -
#  12*F_0**2*\lambda**3*f_0**7 - 4*F_0**2*\lambda**2*f_0**8)*S**2 + (-128*F_0**6
# *f_0**6 + 48*F_0**5*\lambda**2*f_0**5 + 256*F_0**5*\lambda*f_0**6 + 64*F_0**5*
# f_0**7 - 27*F_0**4*\lambda**4*f_0**4 - 72*F_0**4*\lambda**3*f_0**5 - 56*F_0**4
# *\lambda**2*f_0**6 + 32*F_0**4*\lambda*f_0**7 + 16*F_0**4*f_0**8)*S + 256*F_0*
# *6*f_0**6, S, domain='ZZ[F_0,\lambda,f_0]')

# %%
factor(discriminant(Delta_B))
# Out:
#                                                          2
#      12        2   15 ⎛                 2               ⎞  ⎛     3   2       2
# 16⋅F₀  ⋅\lambda ⋅f₀  ⋅⎝4⋅F₀⋅f₀ - \lambda  - 2⋅\lambda⋅f₀⎠ ⋅⎝32⋅F₀ ⋅f₀  + 9⋅F₀
#
#
#         2           2           2        2   3                4
# ⋅\lambda ⋅f₀ + 48⋅F₀ ⋅\lambda⋅f₀  + 48⋅F₀ ⋅f₀  + 27⋅F₀⋅\lambda  + 63⋅F₀⋅\lambd
#
#
#  3                   2   2                   3           4            4
# a ⋅f₀ + 60⋅F₀⋅\lambda ⋅f₀  + 48⋅F₀⋅\lambda⋅f₀  + 24⋅F₀⋅f₀  + 9⋅\lambda ⋅f₀ + 2
#
#                                                           3
#          3   2             2   3                4       5⎞
# 2⋅\lambda ⋅f₀  + 21⋅\lambda ⋅f₀  + 12⋅\lambda⋅f₀  + 4⋅f₀ ⎠

# %%
# Discriminant positif, donc 3 racines

# %%
factor(LC(Delta_B))
# Out:
#                                                                    2
#   2   3                           2 ⎛               2             ⎞
# F₀ ⋅f₀ ⋅(4⋅F₀ + f₀)⋅(\lambda + f₀) ⋅⎝F₀⋅f₀ - \lambda  - \lambda⋅f₀⎠

# %%
#Retour sur B

# %%
B
# Out:
# Poly(Y**4 + (-F_0*S*f_0 - 3*S**2*\lambda**2/8 - 3*S**2*\lambda*f_0/4 - 3*S**2*
# f_0**2/8 + S*\lambda*f_0 + S*f_0**2)*Y**2 + (F_0*S**2*\lambda*f_0/2 + F_0*S**2
# *f_0**2/2 - F_0*S*\lambda*f_0 - 2*F_0*S*f_0**2 + S**3*\lambda**3/8 + 3*S**3*\l
# ambda**2*f_0/8 + 3*S**3*\lambda*f_0**2/8 + S**3*f_0**3/8 - S**2*\lambda**2*f_0
# /2 - S**2*\lambda*f_0**2 - S**2*f_0**3/2)*Y + F_0**2*S*f_0**2 - F_0*S**3*\lamb
# da**2*f_0/16 - F_0*S**3*\lambda*f_0**2/8 - F_0*S**3*f_0**3/16 + F_0*S**2*\lamb
# da**2*f_0/4 + 3*F_0*S**2*\lambda*f_0**2/4 + F_0*S**2*f_0**3/2 - 3*S**4*\lambda
# **4/256 - 3*S**4*\lambda**3*f_0/64 - 9*S**4*\lambda**2*f_0**2/128 - 3*S**4*\la
# mbda*f_0**3/64 - 3*S**4*f_0**4/256 + S**3*\lambda**3*f_0/16 + 3*S**3*\lambda**
# 2*f_0**2/16 + 3*S**3*\lambda*f_0**3/16 + S**3*f_0**4/16, Y, domain='QQ[F_0,S,\
# lambda,f_0]')

# %%
B.coeffs()
# Out:
# ⎡                 2        2      2                 2   2
# ⎢              3⋅S ⋅\lambda    3⋅S ⋅\lambda⋅f₀   3⋅S ⋅f₀
# ⎢1, -F₀⋅S⋅f₀ - ───────────── - ─────────────── - ──────── + S⋅\lambda⋅f₀ + S⋅f
# ⎣                    8                4             8
#
#         2                  2   2                                   3        3
#  2  F₀⋅S ⋅\lambda⋅f₀   F₀⋅S ⋅f₀                               2   S ⋅\lambda
# ₀ , ──────────────── + ───────── - F₀⋅S⋅\lambda⋅f₀ - 2⋅F₀⋅S⋅f₀  + ───────────
#            2               2                                           8
#
#      3        2         3           2    3   3    2        2
#   3⋅S ⋅\lambda ⋅f₀   3⋅S ⋅\lambda⋅f₀    S ⋅f₀    S ⋅\lambda ⋅f₀    2
# + ──────────────── + ──────────────── + ────── - ────────────── - S ⋅\lambda⋅f
#          8                  8             8            2
#
#       2   3                  3        2          3           2       3   3
#  2   S ⋅f₀     2     2   F₀⋅S ⋅\lambda ⋅f₀   F₀⋅S ⋅\lambda⋅f₀    F₀⋅S ⋅f₀    F
# ₀  - ──────, F₀ ⋅S⋅f₀  - ───────────────── - ───────────────── - ───────── + ─
#        2                         16                  8               16
#
#    2        2            2           2       2   3      4        4      4
# ₀⋅S ⋅\lambda ⋅f₀   3⋅F₀⋅S ⋅\lambda⋅f₀    F₀⋅S ⋅f₀    3⋅S ⋅\lambda    3⋅S ⋅\lam
# ──────────────── + ─────────────────── + ───────── - ───────────── - ─────────
#        4                    4                2            256               64
#
#    3         4        2   2      4           3      4   4    3        3
# bda ⋅f₀   9⋅S ⋅\lambda ⋅f₀    3⋅S ⋅\lambda⋅f₀    3⋅S ⋅f₀    S ⋅\lambda ⋅f₀   3
# ─────── - ───────────────── - ──────────────── - ──────── + ────────────── + ─
#                  128                 64            256            16
#
#   3        2   2      3           3    3   4⎤
# ⋅S ⋅\lambda ⋅f₀    3⋅S ⋅\lambda⋅f₀    S ⋅f₀ ⎥
# ──────────────── + ──────────────── + ──────⎥
#        16                 16            16  ⎦

# %%
q = B.coeffs()[1]
sigma = B.coeffs()[-1]
delta_bis = Poly((q**2-4*sigma)/s,s)
delta_bis
# Out:
# Poly((3*\lambda**4/16 + 3*\lambda**3*f_0/4 + 9*\lambda**2*f_0**2/8 + 3*\lambda
# *f_0**3/4 + 3*f_0**4/16)*S**3 + (F_0*\lambda**2*f_0 + 2*F_0*\lambda*f_0**2 + F
# _0*f_0**3 - \lambda**3*f_0 - 3*\lambda**2*f_0**2 - 3*\lambda*f_0**3 - f_0**4)*
# S**2 + (F_0**2*f_0**2 - F_0*\lambda**2*f_0 - 5*F_0*\lambda*f_0**2 - 4*F_0*f_0*
# *3 + \lambda**2*f_0**2 + 2*\lambda*f_0**3 + f_0**4)*S - 4*F_0**2*f_0**2, S, do
# main='QQ[F_0,\lambda,f_0]')

# %%
factor(delta_bis.coeffs())
# Out:
# ⎡                4
# ⎢3⋅(\lambda + f₀)                    2                         ⎛  2
# ⎢─────────────────, f₀⋅(\lambda + f₀) ⋅(F₀ - \lambda - f₀), f₀⋅⎝F₀ ⋅f₀ - F₀⋅\l
# ⎣        16
#
#
#      2                            2          2                  2     3⎞
# ambda  - 5⋅F₀⋅\lambda⋅f₀ - 4⋅F₀⋅f₀  + \lambda ⋅f₀ + 2⋅\lambda⋅f₀  + f₀ ⎠, -4⋅F
#
#
#       ⎤
#  2   2⎥
# ₀ ⋅f₀ ⎥
#       ⎦

# %%
Poly(q/s, s)
# Out:
# Poly((-3*\lambda**2/8 - 3*\lambda*f_0/4 - 3*f_0**2/8)*S - F_0*f_0 + \lambda*f_
# 0 + f_0**2, S, domain='QQ[F_0,\lambda,f_0]')

# %%
Eq = q/s

# %%
solve(Eq,s)
# Out:
# ⎡8⋅f₀⋅(-F₀ + \lambda + f₀)⎤
# ⎢─────────────────────────⎥
# ⎢                    2    ⎥
# ⎣    3⋅(\lambda + f₀)     ⎦

# %%
print(Poly(q/s, s))
# Out:
# Poly((-3*\lambda**2/8 - 3*\lambda*f_0/4 - 3*f_0**2/8)*S - F_0*f_0 + \lambda*f_0 + f_0**2, S, domain='QQ[F_0,\lambda,f_0]')

# %%
latex(q/s)
# Out:
# '\\frac{- F_{0} S f_{0} - \\frac{3 S^{2} \\lambda^{2}}{8} - \\frac{3 S^{2} \\lambda f_{0}}{4} - \\frac{3 S^{2} f_{0}^{2}}{8} + S \\lambda f_{0} + S f_{0}^{2}}{S}'

# %%
latex(factor(q,gens=s))
# Out:
# '- \\frac{S \\left(8 F_{0} f_{0} + S \\left(3 \\lambda^{2} + 6 \\lambda f_{0} + 3 f_{0}^{2}\\right) - 8 \\lambda f_{0} - 8 f_{0}^{2}\\right)}{8}'

# %%
latex(delta_bis)
# Out:
# '\\operatorname{Poly}{\\left( \\left(\\frac{3 \\lambda^{4}}{16} + \\frac{3 \\lambda^{3} f_{0}}{4} + \\frac{9 \\lambda^{2} f_{0}^{2}}{8} + \\frac{3 \\lambda f_{0}^{3}}{4} + \\frac{3 f_{0}^{4}}{16}\\right) S^{3} + \\left(F_{0} \\lambda^{2} f_{0} + 2 F_{0} \\lambda f_{0}^{2} + F_{0} f_{0}^{3} - \\lambda^{3} f_{0} - 3 \\lambda^{2} f_{0}^{2} - 3 \\lambda f_{0}^{3} - f_{0}^{4}\\right) S^{2} + \\left(F_{0}^{2} f_{0}^{2} - F_{0} \\lambda^{2} f_{0} - 5 F_{0} \\lambda f_{0}^{2} - 4 F_{0} f_{0}^{3} + \\lambda^{2} f_{0}^{2} + 2 \\lambda f_{0}^{3} + f_{0}^{4}\\right) S -  4 F_{0}^{2} f_{0}^{2}, S, domain=\\mathbb{Q}\\left[F_{0}, \\lambda, f_{0}\\right] \\right)}'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-4362a6b95108> in <module>
# ----> 1 simplify((q**2-4*sigma)/s, gens=s)
#
# TypeError: simplify() got an unexpected keyword argument 'gens'

# %%
delta_bis
# Out:
# Poly((3*\lambda**4/16 + 3*\lambda**3*f_0/4 + 9*\lambda**2*f_0**2/8 + 3*\lambda
# *f_0**3/4 + 3*f_0**4/16)*S**3 + (F_0*\lambda**2*f_0 + 2*F_0*\lambda*f_0**2 + F
# _0*f_0**3 - \lambda**3*f_0 - 3*\lambda**2*f_0**2 - 3*\lambda*f_0**3 - f_0**4)*
# S**2 + (F_0**2*f_0**2 - F_0*\lambda**2*f_0 - 5*F_0*\lambda*f_0**2 - 4*F_0*f_0*
# *3 + \lambda**2*f_0**2 + 2*\lambda*f_0**3 + f_0**4)*S - 4*F_0**2*f_0**2, S, do
# main='QQ[F_0,\lambda,f_0]')

# %%
latex(delta_bis.args[0])
# Out:
# '- 4 F_{0}^{2} f_{0}^{2} + S^{3} \\left(\\frac{3 \\lambda^{4}}{16} + \\frac{3 \\lambda^{3} f_{0}}{4} + \\frac{9 \\lambda^{2} f_{0}^{2}}{8} + \\frac{3 \\lambda f_{0}^{3}}{4} + \\frac{3 f_{0}^{4}}{16}\\right) + S^{2} \\left(F_{0} \\lambda^{2} f_{0} + 2 F_{0} \\lambda f_{0}^{2} + F_{0} f_{0}^{3} - \\lambda^{3} f_{0} - 3 \\lambda^{2} f_{0}^{2} - 3 \\lambda f_{0}^{3} - f_{0}^{4}\\right) + S \\left(F_{0}^{2} f_{0}^{2} - F_{0} \\lambda^{2} f_{0} - 5 F_{0} \\lambda f_{0}^{2} - 4 F_{0} f_{0}^{3} + \\lambda^{2} f_{0}^{2} + 2 \\lambda f_{0}^{3} + f_{0}^{4}\\right)'

# %%
sous_poly = Poly(discriminant(B)/s**3,gens=s)
sous_poly
# Out:
# Poly((4*F_0**5*\lambda**2*f_0**5 + 8*F_0**5*\lambda*f_0**6 + 4*F_0**5*f_0**7 -
#  8*F_0**4*\lambda**4*f_0**4 - 24*F_0**4*\lambda**3*f_0**5 - 23*F_0**4*\lambda*
# *2*f_0**6 - 6*F_0**4*\lambda*f_0**7 + F_0**4*f_0**8 + 4*F_0**3*\lambda**6*f_0*
# *3 + 16*F_0**3*\lambda**5*f_0**4 + 22*F_0**3*\lambda**4*f_0**5 + 10*F_0**3*\la
# mbda**3*f_0**6 - 2*F_0**3*\lambda**2*f_0**7 - 2*F_0**3*\lambda*f_0**8 + F_0**2
# *\lambda**6*f_0**4 + 4*F_0**2*\lambda**5*f_0**5 + 6*F_0**2*\lambda**4*f_0**6 +
#  4*F_0**2*\lambda**3*f_0**7 + F_0**2*\lambda**2*f_0**8)*S**3 + (16*F_0**6*f_0*
# *6 - 60*F_0**5*\lambda**2*f_0**5 - 96*F_0**5*\lambda*f_0**6 - 32*F_0**5*f_0**7
#  + 12*F_0**4*\lambda**4*f_0**4 + 62*F_0**4*\lambda**3*f_0**5 + 74*F_0**4*\lamb
# da**2*f_0**6 + 16*F_0**4*\lambda*f_0**7 - 8*F_0**4*f_0**8 - 18*F_0**3*\lambda*
# *5*f_0**4 - 52*F_0**3*\lambda**4*f_0**5 - 42*F_0**3*\lambda**3*f_0**6 + 8*F_0*
# *3*\lambda*f_0**8 - 4*F_0**2*\lambda**5*f_0**5 - 12*F_0**2*\lambda**4*f_0**6 -
#  12*F_0**2*\lambda**3*f_0**7 - 4*F_0**2*\lambda**2*f_0**8)*S**2 + (-128*F_0**6
# *f_0**6 + 48*F_0**5*\lambda**2*f_0**5 + 256*F_0**5*\lambda*f_0**6 + 64*F_0**5*
# f_0**7 - 27*F_0**4*\lambda**4*f_0**4 - 72*F_0**4*\lambda**3*f_0**5 - 56*F_0**4
# *\lambda**2*f_0**6 + 32*F_0**4*\lambda*f_0**7 + 16*F_0**4*f_0**8)*S + 256*F_0*
# *6*f_0**6, S, domain='ZZ[F_0,\lambda,f_0]')

# %%
latex(factor(LC(sous_poly)))
# Out:
# 'F_{0}^{2} f_{0}^{3} \\left(4 F_{0} + f_{0}\\right) \\left(\\lambda + f_{0}\\right)^{2} \\left(F_{0} f_{0} - \\lambda^{2} - \\lambda f_{0}\\right)^{2}'

# %%
latex(factor(discriminant(sous_poly)))
# Out:
# '16 F_{0}^{12} \\lambda^{2} f_{0}^{15} \\left(4 F_{0} f_{0} - \\lambda^{2} - 2 \\lambda f_{0}\\right)^{2} \\left(32 F_{0}^{3} f_{0}^{2} + 9 F_{0}^{2} \\lambda^{2} f_{0} + 48 F_{0}^{2} \\lambda f_{0}^{2} + 48 F_{0}^{2} f_{0}^{3} + 27 F_{0} \\lambda^{4} + 63 F_{0} \\lambda^{3} f_{0} + 60 F_{0} \\lambda^{2} f_{0}^{2} + 48 F_{0} \\lambda f_{0}^{3} + 24 F_{0} f_{0}^{4} + 9 \\lambda^{4} f_{0} + 22 \\lambda^{3} f_{0}^{2} + 21 \\lambda^{2} f_{0}^{3} + 12 \\lambda f_{0}^{4} + 4 f_{0}^{5}\\right)^{3}'

# %%
latex(factor(discriminant(sous_poly)))
# Out:
# '16 F_{0}^{12} \\lambda^{2} f_{0}^{15} \\left(4 F_{0} f_{0} - \\lambda^{2} - 2 \\lambda f_{0}\\right)^{2} \\left(32 F_{0}^{3} f_{0}^{2} + 9 F_{0}^{2} \\lambda^{2} f_{0} + 48 F_{0}^{2} \\lambda f_{0}^{2} + 48 F_{0}^{2} f_{0}^{3} + 27 F_{0} \\lambda^{4} + 63 F_{0} \\lambda^{3} f_{0} + 60 F_{0} \\lambda^{2} f_{0}^{2} + 48 F_{0} \\lambda f_{0}^{3} + 24 F_{0} f_{0}^{4} + 9 \\lambda^{4} f_{0} + 22 \\lambda^{3} f_{0}^{2} + 21 \\lambda^{2} f_{0}^{3} + 12 \\lambda f_{0}^{4} + 4 f_{0}^{5}\\right)^{3}'

# %%
factor(sous_poly(0))
# Out:
#       6   6
# 256⋅F₀ ⋅f₀
